# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# %%
df=pd.read_csv('dados_limpos.csv',encoding='latin1', parse_dates=['DATA'])
df.head()
# Out:
#     ANO  MES       SENADOR           TIPO_DESPESA            CNPJ_CPF  \
# 0  2016    1  ACIR GURGACZ                Aluguel  05.914.650/0001-66
# 1  2016    1  ACIR GURGACZ                Aluguel  05.914.650/0001-66
# 2  2016    1  ACIR GURGACZ                Aluguel      004.948.028-63
# 3  2016    1  ACIR GURGACZ                Aluguel  05.423.963/0001-11
# 4  2016    1  ACIR GURGACZ  Aquisição de Material  62.652.961/0001-38
#
#                          FORNECEDOR  DOCUMENTO       DATA  \
# 0  ELETROBRÁS DISTRIBUIÇÃO RONDÔNIA  000011328 2016-01-13
# 1  ELETROBRÁS DISTRIBUIÇÃO RONDÔNIA  000011327 2016-01-18
# 2     GILBERTO PISELO DO NASCIMENTO     001/16 2016-04-01
# 3                     OI MÓVEL S.A.  661639001 2016-01-16
# 4               AGÊNCIA ESTADO S.A.   00608918 2016-06-01
#
#                                         DETALHAMENTO  VALOR_REEMBOLSADO  DIA
# 0  Despesa com pagamento de energia elétrica para...              73.60   13
# 1  Pagamento de energia elétrica para o escritóri...             206.84   18
# 2  Despesa com pagamento de aluguel, utilizado pa...            6000.00    1
# 3  despesa com pagamento de telefonia para o escr...             407.48   16
# 4  Aquisição de publicação virtual de conteúdo jo...             550.00    1

# %%
df.dtypes
# Out:
# ANO                           int64
# MES                           int64
# SENADOR                      object
# TIPO_DESPESA                 object
# CNPJ_CPF                     object
# FORNECEDOR                   object
# DOCUMENTO                    object
# DATA                 datetime64[ns]
# DETALHAMENTO                 object
# VALOR_REEMBOLSADO           float64
# DIA                           int64
# dtype: object

# %%
df.describe()
# Out:
#            ANO           MES  VALOR_REEMBOLSADO           DIA
# count  26688.0  26688.000000       26688.000000  26688.000000
# mean    2016.0      6.470736         947.489558     15.430680
# std        0.0      3.257139        2733.963252      8.846572
# min     2016.0      1.000000           0.010000      1.000000
# 25%     2016.0      4.000000         123.997500      8.000000
# 50%     2016.0      6.000000         324.745000     15.000000
# 75%     2016.0      9.000000         956.762500     23.000000
# max     2016.0     12.000000      256980.000000     31.000000

# %%
df[df['VALOR_REEMBOLSADO']==256980]
# Out:
#        ANO  MES          SENADOR TIPO_DESPESA            CNPJ_CPF  \
# 4637  2016   12  DAVI ALCOLUMBRE  Divulgações  04.953.008/0001-23
#
#                                      FORNECEDOR DOCUMENTO       DATA  \
# 4637  ARTE & IMAGEM GRAFICA E EDITORA EIRELI ME       202 2017-03-22
#
#      DETALHAMENTO  VALOR_REEMBOLSADO  DIA
# 4637          NaN           256980.0   22

# %%
senadores_com_mais_gastos=df.groupby('SENADOR')['VALOR_REEMBOLSADO'].sum()
senadores_com_mais_gastos=senadores_com_mais_gastos.sort_values(ascending=False)

# %%
senadores_com_mais_gastos.head(10).plot(kind='barh', color='pink', figsize=(17,10))
plt.title('Top 10 senandores com mais reembolsos')
plt.ylabel('Valor reembolsado')
plt.savefig('top_10_senadores_gastos.png')
plt.show()

# %%
plt.figure(figsize=(17,10))
sns.countplot(x=df['TIPO_DESPESA'])
plt.title('Total de despesas por categorias')
plt.ylabel('Total de despesas')
plt.xlabel('Tipo de despesa')
plt.show()

# %%
df['ANO_MES']=df['DATA'].dt.strftime('%Y-%m')

# %%
pivot_df=df.pivot_table(index='ANO_MES', 
               columns='TIPO_DESPESA', 
               values='VALOR_REEMBOLSADO', 
               aggfunc=np.sum,
              fill_value=0)
pivot_df=pivot_df.loc['2016-01':'2016-12']

# %%
plt.figure(figsize=(17,10))
sns.heatmap(pivot_df, annot=True, fmt='.2f', cmap='Blues')
plt.show()

# %%
df.loc[df['ANO_MES']=='1977-10']
# Out:
#         ANO  MES     SENADOR TIPO_DESPESA            CNPJ_CPF  \
# 17926  2016   10  PAULO PAIM    Logística  37.063.328/0030-00
#
#                                      FORNECEDOR DOCUMENTO       DATA  \
# 17926  Auto Shopping Derivados de Petroleo Ltda    621942 1977-10-10
#
#                                             DETALHAMENTO  VALOR_REEMBOLSADO  \
# 17926  Aquisição de combustível para veículos utiliza...             152.51
#
#        DIA  ANO_MES
# 17926   10  1977-10

# %%
pivot_df.loc['2016-01']
# Out:
# TIPO_DESPESA
# Aluguel                    0.0
# Aquisição de Material      0.0
# Contratação                0.0
# Divulgações                0.0
# Logística                675.0
# Passagens                  0.0
# Segurança                  0.0
# Name: 2013-09, dtype: float64

# %%
pivot_df
# Out:
# TIPO_DESPESA    Aluguel  Aquisição de Material  Contratação  Divulgações  \
# ANO_MES
# 1977-10            0.00                   0.00         0.00         0.00
# 1986-03            0.00                   0.00         0.00         0.00
# 2012-02          162.40                   0.00         0.00         0.00
# 2013-09            0.00                   0.00         0.00         0.00
# 2014-01            0.00                   0.00         0.00         0.00
# 2014-04            0.00                   0.00         0.00         0.00
# 2014-10            0.00                   0.00         0.00         0.00
# 2015-01          570.62                   0.00         0.00         0.00
# 2015-02          403.39                  39.00      1000.00         0.00
# 2015-03            0.00                   0.00         0.00         0.00
# 2015-05         1637.17                 500.03         0.00         0.00
# 2015-06          562.94                   0.00         0.00         0.00
# 2015-07           92.25                1790.00         0.00         0.00
# 2015-08            0.00                   0.00         0.00         0.00
# 2015-09          406.13                   0.00         0.00         0.00
# 2015-10         7511.87                   0.00         0.00         0.00
# 2015-11         5000.00                 104.25         0.00         0.00
# 2015-12        16316.99                4113.25         0.00         0.00
# 2016-01       681720.72              130287.53    519205.27    419496.30
# 2016-02       355621.91              103718.82    286143.29    252818.74
# 2016-03       361367.60               94986.41    255112.80    291705.97
# 2016-04       392789.93               93684.00    243225.69    224044.85
# 2016-05       765999.20               80266.83    275629.88    263856.45
# 2016-06       371057.80               90153.46    219292.74    320627.83
# 2016-07       306088.26               67689.75    136238.66    200566.67
# 2016-08       252439.17               78291.64    202764.55    256752.60
# 2016-09       334052.65               78875.75    107722.85    200740.90
# 2016-10       501062.14               67328.87    164543.91    177911.21
# 2016-11       284476.07               82938.67    292906.28    245109.00
# 2016-12       276560.04               73595.38    269498.04    306955.27
# 2017-01        15810.91                1200.00     11000.00     20420.00
# 2017-02        13407.33                 139.70     35700.00         0.00
# 2017-03          826.59                   0.00     85350.00    397660.00
